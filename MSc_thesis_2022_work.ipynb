# %%
import numpy as np
import matplotlib
from astropy.io import ascii
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pylab as pl
from astropy.table import Table
import seaborn as sns

# %%
A1= Table.read('AGN_cross_match_Chandra.fits')
A1
# Out:
# <Table length=5>
# Best_match All_match Arc\sec
#   int16      int16    int16
# ---------- --------- -------
#       1183      1188       1
#       1293      1326       2
#       1310      1352       3
#       1323      1382       4
#       1331      1400       5

# %%
A2= Table.read('AGN_cross_match_XMM.fits')
A2
# Out:
# <Table length=5>
# Best_match All_match Arc\sec
#   int16      int16    int16
# ---------- --------- -------
#        358       359       1
#        685       699       2
#        849       886       3
#        900       952       4
#        927       989       5

# %% [markdown]
# ## AGN_Cross_matching_Chandra_and_AGN and_XMM_Newton

# %%
plt.figure(1, figsize=(16, 8))

plt.plot(A1['Arc\sec'], A1['Best_match'], color='red', label='Best_match',linewidth=3.0,marker='d',markerfacecolor='red',markersize=15)
plt.plot(A1['Arc\sec'], A1['All_match'], color='blue', label='All_match',linewidth=3.0, linestyle='dashed',marker='o',markerfacecolor='blue',markersize=15)
plt.xlim(0.9,  5.2)

plt.xlabel('Radius  (arcsec)', fontsize=25)
plt.ylabel('Number of  sources', fontsize=25)
plt.rc('xtick',labelsize=22)
plt.rc('ytick',labelsize=22)

plt.savefig('AGN_cross_match_Chandra.jpg',dpi=400)
plt.legend(loc=2, fontsize=17)
#plt.title("AGN_cross_match_with_Chandra",fontsize=22)

# %%
plt.figure(1, figsize=(16, 8))

plt.plot(A2['Arc\sec'], A2['Best_match'], color='red', label='Best_match',linewidth=3.0,marker='d',markerfacecolor='red',markersize=15)
plt.plot(A2['Arc\sec'], A2['All_match'], color='blue', label='All_match',linewidth=3.0, linestyle='dashed',marker='o',markerfacecolor='blue',markersize=15)
plt.xlim(0.9,  5.2)

plt.xlabel('Radius  (arcsec)', fontsize=25)
plt.ylabel('Number of  sources', fontsize=25)
plt.rc('xtick',labelsize=22)
plt.rc('ytick',labelsize=22)

plt.savefig('AGN_cross_match_XMM.jpg',dpi=400)
plt.legend(loc=2, fontsize=17)
#plt.title("AGN_cross_match_with_Chandra",fontsize=22)

# %%
B1= Table.read('All.fits')
B1
# Out:
# <Table masked=True length=1472>
#   ID_1       RA_1      Dec_1   ...    frequency_2       Radio_luminosity
#                                ...         Hz
# float32    float64    float64  ...      float64             float64
# -------- ----------- --------- ... ----------------- ---------------------
#   8362.0 149.5439148 1.8673762 ... 394736842105263.1                   nan
#   9649.0 149.5184937 1.9075274 ... 394736842105263.1                   nan
#  10943.0 149.5549927 1.9885179 ... 394736842105263.1                   nan
#  10960.0 149.5549164 2.0001783 ... 394736842105263.1                   nan
#  10972.0 149.5511627 1.9885041 ... 394736842105263.1                   nan
#  12014.0  149.526001 2.0204754 ... 394736842105263.1                   nan
#  12228.0  149.561264 2.0091538 ... 394736842105263.1 8.478033640484569e+22
#  13008.0 149.5648956 2.0923908 ... 394736842105263.1                   nan
#  13069.0 149.5555573  2.093369 ... 394736842105263.1                   nan
# ...

# %%
plt.figure(1, figsize=(16, 8))
markersize=120
plt.scatter(B1['RA_x_2'], B1['DEC_x_2'], color='blue', edgecolors= 'k', s= 130, cmap= 'Dark2', marker='D', linewidth=1, label='Chandra')
plt.scatter(B1['ra_2'], B1['dec_2'], color='red', edgecolors= 'k', s= 130, cmap= 'Dark', marker='<', linewidth=1, label='XMM-Newton')
plt.scatter(B1['RA2000'],B1['DEC2000'], color='green', edgecolors= 'k', s=130, cmap= 'Dark2',  marker='s', linewidth=1, label='1.4GHz')
plt.scatter(B1['RAJ2000_2'],B1['DEJ2000_2'], color='yellow', edgecolors= 'k', s= 130, cmap= 'Dark2', marker='d', linewidth=1,label='3GHz' )
plt.xlabel('RA [Deg]', fontsize=25)
plt.ylabel('Dec [Deg]', fontsize=25)
plt.rc('xtick',labelsize=25)
plt.rc('ytick',labelsize=25)
plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=18)
plt.savefig('file10.png',dpi=400)

plt.show()

# %%
B2= Table.read('BC.fits')
B2
# Out:
# <Table masked=True length=522>
#   ID_1       RA_1      Dec_1   ...  HR_77   HR_88         HR_99
#                                ...
# float32    float64    float64  ... float64 float64       float64
# -------- ----------- --------- ... ------- ------- --------------------
#  10943.0 149.5549927 1.9885179 ...   -58.0   132.0  -0.4393939393939394
#  10972.0 149.5511627 1.9885041 ...     nan     nan                  nan
#  13069.0 149.5555573  2.093369 ...  -245.0   393.0  -0.6234096692111959
#  15913.0 149.5985413 2.2003093 ...     nan     nan                  nan
#  18334.0 149.5851898 1.9919548 ...     nan     nan                  nan
#  19725.0  149.619278 2.0245099 ...     nan     nan                  nan
#  19805.0 149.6073608 2.0176179 ...     nan     nan                  nan
#  19895.0  149.595871 2.0407147 ...   -25.0   107.0  -0.2336448598130841
#  19962.0 149.5810089 2.0067356 ...     nan     nan                  nan
# ...

# %%
B3= Table.read('GV.fits')
B3
# Out:
# <Table masked=True length=606>
#   ID_1       RA_1      Dec_1   ...  HR_77   HR_88         HR_99
#                                ...
# float32    float64    float64  ... float64 float64       float64
# -------- ----------- --------- ... ------- ------- -------------------
#   8362.0 149.5439148 1.8673762 ...     nan     nan                 nan
#   9649.0 149.5184937 1.9075274 ...    15.0   133.0 0.11278195488721804
#  12014.0  149.526001 2.0204754 ...   -68.0   236.0  -0.288135593220339
#  13008.0 149.5648956 2.0923908 ...     nan     nan                 nan
#  18402.0 149.5703735 1.9905663 ...   -82.0   272.0 -0.3014705882352941
#  18417.0  149.563858 1.9630669 ...     nan     nan                 nan
#  21151.0 149.6051331 2.0522935 ...   -50.0    50.0                -1.0
#  22219.0 149.6411133 2.1076314 ...     nan     nan                 nan
#  25677.0  149.648819 2.2327533 ...    75.0    75.0                 1.0
# ...

# %%
B4= Table.read('RS.fits')
B4
# Out:
# <Table masked=True length=292>
#   ID_1       RA_1      Dec_1   ...  HR_77   HR_88         HR_99
#                                ...
# float32    float64    float64  ... float64 float64       float64
# -------- ----------- --------- ... ------- ------- --------------------
#  12228.0  149.561264 2.0091538 ...   -68.0    68.0                 -1.0
#  18374.0 149.5786896 2.0017781 ...   -50.0    50.0                 -1.0
#  23918.0 149.6211243 2.1810327 ...     nan     nan                  nan
#  25624.0 149.6496277 2.2092495 ...     nan     nan                  nan
#  25864.0 149.6217651 2.2170653 ...     nan     nan                  nan
#  26673.0 149.6625214 2.2695825 ...   -74.0   212.0  -0.3490566037735849
#  27484.0 149.6393127 2.0031817 ...     8.0   216.0 0.037037037037037035
# -30660.0 149.6806946  2.268281 ...    62.0    62.0                  1.0
# -30524.0 149.6958618 2.2645054 ...   -29.0   849.0 -0.03415783274440518
# ...

# %% [markdown]
# # Optical mutiwavelength Catalog

# %% [markdown]
# ##  1. U_B
# ## 2. Redshifts
# ## 3. Stellar mass
# ## 4. Absolute magntitude

# %%
#from mpl_toolkits.mplot3d import Axes3D 
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline
fig, ax = plt.subplots(figsize =(14, 8))
plt.xlabel('U-B rest-frame', fontsize=22)
plt.ylabel('Number of sources', fontsize=22)
ax.set_xlim(0.02, 3)
ax.set_ylim(0, 220)
plt.hist(B2['U_B'], color='blue', label='BC_AGN',bins=7,edgecolor='black',align='right',alpha=1, rwidth=3.0,linewidth=3) 
plt.hist(B3['U_B'], color='green',label='GV_AGN',bins=4,edgecolor='black',align='right',alpha=1, rwidth=3.0,linewidth=3) 
plt.hist(B4['U_B'], color='red',  label='RS_AGN',bins=16,edgecolor='black',align='right',alpha=1, rwidth=3.0,linewidth=3) 
#title = fig.suptitle("AGN_selection_of_BC_GV_RS",fontsize=22)
plt.rc('xtick',labelsize=21)
plt.rc('ytick',labelsize=21)

plt.savefig('file12.png',dpi=400)
plt.legend(loc=1,fontsize=18)
plt.show()

# %%
fig, ax = plt.subplots(figsize =(14, 8))
plt.xlabel('Redshift ',fontsize=22)
plt.ylabel('Normalised number of sources', fontsize=22)
ax.set_xlim(-0.3, 5)
ax.set_ylim(0, 1.2)
plt.hist(B2['zphot_salvato'], align='left', color='blue',label='BC_AGN',bins=330, edgecolor='blue',linewidth=1.5,density=True, lw=3.5,alpha=1,linestyle='solid',histtype='step')
plt.hist(B3['zphot_salvato'],  color='green',label='GV_AGN',bins=330,edgecolor='green',linewidth=1.5,density=True,lw=3.5, alpha=1, linestyle='dashdot',histtype='step')
plt.hist(B4['zphot_salvato'], align='right', color='red',label='RS_AGN',bins=330 ,edgecolor='red',linewidth=1.5,density=True,lw=4.5,  alpha=0.9, linestyle='dashed',histtype='step')
title= fig.suptitle("AGN_selection_of_BC_GV_RS",fontsize=22)
plt.rc('xtick',labelsize=23)
plt.rc('ytick',labelsize=23)
plt.savefig('file.jpg',dpi=400)
plt.legend(loc=1,fontsize=16)
plt.show()

# %%
fig, ax = plt.subplots(figsize =(14, 8))
plt.xlabel('Absolute mgnitude(B_band)',fontsize=22)
plt.ylabel('Normalised number of  sources', fontsize=22)
ax.set_xlim(-29, -14)
ax.set_ylim(0, 0.5)

plt.hist(B2['MagAbs70_B_subaru'], color='blue',label='BC_AGN',bins=range(-28,-14,1),edgecolor='blue',linewidth=3, rwidth=1.0, histtype='step',linestyle='solid',density=True,lw=3.5,alpha=1,fill=False)
plt.hist(B3['MagAbs70_B_subaru'], color='green',label='GV_AGN',bins=range(-28,-14,1),edgecolor='green',linewidth=3, rwidth=1.0,histtype='step',linestyle='dashdot',density=True,lw=3.5,alpha=1,fill=False)
plt.hist(B4['MagAbs70_B_subaru'], color='red',label='RS_AGN',bins=range(-28,-14,1),edgecolor='red',linewidth=3, rwidth=1.0,histtype='step',linestyle='dashed',density=True,lw=4.5,alpha=1,fill=False)
title= fig.suptitle("AGN_selection_of_BC_GV_RS",fontsize=22)
plt.rc('xtick',labelsize=23)
plt.rc('ytick',labelsize=23)
plt.savefig('file4.jpg',dpi=400)
plt.legend(loc=1,fontsize=16)

# %%
fig, ax = plt.subplots(figsize =(14, 8))
plt.xlabel('Absolute magnitude (F814W_band)',fontsize=22)
plt.ylabel('Normalised number of sources', fontsize=22)
ax.set_xlim(-29, -14)
ax.set_ylim(0, 0.5)

plt.hist(B2['MagAbs70_f814w'], color='blue',label='BC_AGN',bins=range(-28,-14,1),edgecolor='blue',linewidth=3,lw=3.5,fill=False,histtype='step', linestyle='solid',density=True)
plt.hist(B3['MagAbs70_f814w'], color='green',label='GV_AGN',bins=range(-28,-14,1),edgecolor='green',linewidth=3,lw=3.5,fill=False,histtype='step',linestyle='dashdot',density=True)
plt.hist(B4['MagAbs70_f814w'], color='red',label='RS_AGN',bins=range(-28,-14,1),edgecolor='red',linewidth=3,lw=4.5,fill=False,histtype='step',linestyle='dashed',density=True)
title= fig.suptitle("AGN_selection_of_BC_GV_RS",fontsize=22)
plt.rc('xtick',labelsize=23)
plt.rc('ytick',labelsize=23)
plt.savefig('file4.jpg',dpi=400)
plt.legend(loc=1,fontsize=16)

# %%
C1= Table.read('BC_subsample_FINAL_AGNcat_U-B.fits')
C1
# Out:
# <Table length=522>
#    ID         RA        Dec    ...  Fhard_Foptisubaru  Fhard_Foptisubaru23
# float32    float64    float64  ...       float64             float64
# -------- ----------- --------- ... ------------------- --------------------
#  10943.0 149.5549927 1.9885179 ...  0.5611517571000868 -0.25091967286430467
#  10972.0 149.5511627 1.9885041 ...  0.6454284973876093 -0.19015186325042652
#  13069.0 149.5555573  2.093369 ... 0.20553972606216364  -0.6871042266239509
#  15913.0 149.5985413 2.2003093 ...   0.521824199346821 -0.28247578457060746
#  18334.0 149.5851898 1.9919548 ...  1.0697708299230955   0.0292907515547421
#  19725.0  149.619278 2.0245099 ... 0.43924188928342817  -0.3572962491200267
#  19805.0 149.6073608 2.0176179 ... 0.34661546443609126  -0.4601520649070518
#  19895.0  149.595871 2.0407147 ... 0.19797449911264078  -0.7033907471521349
#  19962.0 149.5810089 2.0067356 ...   0.914745210161526 -0.03869985591171804
# ...

# %%
C2= Table.read('GV_subsample_FINAL_AGNcat_U-B.fits')
C2
# Out:
# <Table length=606>
#    ID         RA        Dec    ...  Fhard_Foptisubaru   Fhard_Foptisubaru23
# float32    float64    float64  ...       float64              float64
# -------- ----------- --------- ... ------------------- ---------------------
#   8362.0 149.5439148 1.8673762 ...  0.9379448189714978 -0.027822711217009778
#   9649.0 149.5184937 1.9075274 ... 0.17811042421481668   -0.7493106619713995
#  12014.0  149.526001 2.0204754 ...  0.2268938518525724   -0.6441772720422448
#  13008.0 149.5648956 2.0923908 ...  1.2533665262361262   0.09807809178004928
#  18402.0 149.5703735 1.9905663 ...  0.7808404126101202  -0.10743771772944229
#  18417.0  149.563858 1.9630669 ...  1.7434919855814113   0.24141995536799268
#  21151.0 149.6051331 2.0522935 ...   1.159898319563833   0.06441991923738427
#  22219.0 149.6411133 2.1076314 ...  0.6843321333225239  -0.16473306690561665
#  25677.0  149.648819 2.2327533 ... 0.14713870657379763   -0.8322730659524252
# ...

# %%
C3= Table.read('RS_subsample_FINAL_AGNcat_U-B.fits')
C3
# Out:
# <Table length=292>
#    ID         RA        Dec    ...  Fhard_Foptisubaru   Fhard_Foptisubaru23
# float32    float64    float64  ...       float64              float64
# -------- ----------- --------- ... ------------------- ----------------------
#  12228.0  149.561264 2.0091538 ...  1.0576806141457005    0.02435454439610645
#  18374.0 149.5786896 2.0017781 ...   0.572793736286124   -0.24200173984692963
#  23918.0 149.6211243 2.1810327 ...  1.9987622849463875    0.30076114605662024
#  25624.0 149.6496277 2.2092495 ... 0.32065315143012735   -0.49396448741058496
#  25864.0 149.6217651 2.2170653 ...  3.7311856954815226     0.5718468637596922
#  26673.0 149.6625214 2.2695825 ... 0.22908077062954102     -0.640011364586147
#  27484.0 149.6393127 2.0031817 ...  2.7548980024474354     0.4401055241336246
# -30660.0 149.6806946  2.268281 ...  0.9879953388340079 -0.0052451043227410635
# -30524.0 149.6958618 2.2645054 ...  1.4224814761878846    0.15304661964231742
# ...

# %%
fig, ax = plt.subplots(figsize =(14, 8))
plt.xlabel('log($M{_*}$)[$M_{\odot}$]',fontsize=22)
plt.ylabel('Normalised number of  sources', fontsize=22)
ax.set_xlim(8, 12.5)
ax.set_ylim(0, 1.3)

plt.hist(C1['mass70'], color='blue',label='BC_AGN',bins=2800,edgecolor='blue',linewidth=2,  histtype='step',density=True,lw=3.5,alpha=1,fill=False, linestyle='solid')
plt.hist(C2['mass70'], color='green',label='GV_AGN',bins=2800,edgecolor='green',linewidth=2,histtype='step',density=True,lw=3.5,alpha=1,fill=False, linestyle='dashdot')
plt.hist(C3['mass70'], color='red',label='RS_AGN',bins=2900,edgecolor='red',linewidth=2, histtype='step',density=True,lw=4.5,alpha=1,fill=False, linestyle='dashed')
title= fig.suptitle("AGN_selection_of_BC_GV_RS",fontsize=22)
plt.rc('xtick',labelsize=23)
plt.rc('ytick',labelsize=23)
plt.savefig('file4.jpg',dpi=400)
plt.legend(loc=1,fontsize=16)
plt.show()

# %% [markdown]
# # X-RAY to optical flux ratio

# %%
plt.figure(1, figsize=(16, 8))
markersize=120
plt.scatter(B2['zphot_salvato'], B2['log(kcorrected_luminocity_flux_H)'], color='blue', edgecolors= 'k', s= 130, cmap= 'Dark2', marker='D', linewidth=1, label='BC_AGN')
plt.scatter(B3['zphot_salvato'], B3['log(kcorrected_luminocity_flux_H)'], color='green', edgecolors= 'k', s= 130, cmap= 'Dark2', marker='+', linewidth=4, label='GV_AGN')
plt.scatter(B4['zphot_salvato'], B4['log(kcorrected_luminocity_flux_H)'], color='none', edgecolors= 'red', s= 130, cmap= 'Dark2', marker='s', linewidth=2, label='RS_AGN')
plt.xlabel('redshfits', fontsize=25)
plt.ylabel('loglLx(2-10) erg/sec', fontsize=25)
plt.rc('xtick',labelsize=25)
plt.rc('ytick',labelsize=25)
plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=18)
plt.savefig('file10.png',dpi=400)
plt.show()

# %%
plt.figure(1, figsize=(16, 8))
markersize=120
plt.scatter(B1['zphot_salvato'], B1['log(kcorrected_luminocity_flux_H)'], color='red', edgecolors= 'red', s= 160, cmap= 'Dark2', marker='^', linewidth=2, label='Chandra')
plt.scatter(B1['zphot_salvato'], B1['log10(Kcorrected_lum_210)'], color='none', edgecolors= 'green', s= 160, cmap= 'Dark2', marker='D', linewidth=3, label='XMM netwon ')
plt.xlabel('redshfits', fontsize=25)
plt.ylabel('loglLx(2-10) erg/sec', fontsize=25)
plt.rc('xtick',labelsize=25)
plt.rc('ytick',labelsize=25)
plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=18)
plt.savefig('file10.png',dpi=400)

plt.show()

# %%
plt.figure(1, figsize=(14, 8))
markersize=120
plt.scatter(B2['mass70'], B2['log(kcorrected_luminocity_flux_H)'], color='blue', edgecolors= 'k', s= 130, cmap= 'Dark2', marker='D', linewidth=1, label='BC_AGN')
plt.scatter(B3['mass70'], B3['log(kcorrected_luminocity_flux_H)'], color='green', edgecolors= 'k', s= 150, cmap= 'Dark2', marker='+', linewidth=4, label='GV_AGN')
plt.scatter(B4['mass70'], B4['log(kcorrected_luminocity_flux_H)'], color='none', edgecolors= 'red', s= 130, cmap= 'Dark2', marker='s', linewidth=2, label='RS_AGN')
plt.xlim(8, 12)

plt.xlabel('log($M{_*}$)[$M_{\odot}$]', fontsize=25)
plt.ylabel('loglLx(2-10) erg/sec', fontsize=25)
plt.rc('xtick',labelsize=25)
plt.rc('ytick',labelsize=25)
plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=18)
plt.savefig('file10.png',dpi=400)

plt.show()

# %%
C5= Table.read('BCC.fits')
C5
# Out:
# <Table masked=True length=36>
#   ID_1       RA_1      Dec_1   ... Log_x_to_optical     HR_12_FINAL
#                                ...
# float32    float64    float64  ...     float64            float64
# -------- ----------- --------- ... ---------------- --------------------
#  22299.0 149.6382141 2.1495957 ...    30000000000.0 -0.28802588996763756
# -29501.0 149.7207336 2.3489881 ...    30000000000.0  -0.6069364161849711
# -26732.0 149.7058258 2.4198005 ...    30000000000.0  -0.7423056859676578
# -23019.0 149.7710724 2.2584734 ...    30000000000.0  -0.5164835164835165
# -13216.0 149.8340454 2.3087234 ...    30000000000.0 -0.44113475177304967
#  -5927.0 149.8590546 2.2582619 ...    30000000000.0 -0.47477064220183485
#   6569.0  149.936615 2.6802056 ...    30000000000.0  -0.6284584980237155
#  10076.0 149.9556122 2.5020289 ...    30000000000.0  -0.5096359743040685
#  19075.0 150.0044861 2.2370987 ...    30000000000.0  -0.6013400335008375
# ...

# %%
C6= Table.read('GVV.fits')
C6
# Out:
# <Table masked=True length=41>
#   ID_1       RA_1      Dec_1   ... Log_x_to_optical     HR_12_FINAL
#                                ...
# float32    float64    float64  ...     float64            float64
# -------- ----------- --------- ... ---------------- --------------------
#  28917.0   149.66922 2.0740416 ...    30000000000.0 -0.41238012205754143
# -28267.0    149.7388 2.3663437 ...    30000000000.0  -0.5910112359550562
# -18641.0 149.7681274 2.4313455 ...    30000000000.0 -0.08411214953271028
# -17759.0 149.7819061 2.1390696 ...    30000000000.0  -0.5251141552511416
# -12899.0 149.7897644 2.3212087 ...    30000000000.0  -0.6311413454270597
#  -8450.0 149.8620453 1.8948123 ...    30000000000.0  -0.1864951768488746
#  -1628.0 149.8935547 2.1076827 ...    30000000000.0   -0.553623188405797
#   9804.0 149.9389801 2.1748469 ...    30000000000.0  0.19696969696969696
#  20125.0 150.0120544 2.5255387 ...    30000000000.0  0.31063829787234043
# ...

# %%
C7= Table.read('RSS.fits')
C7
# Out:
# <Table masked=True length=15>
#   ID_1       RA_1      Dec_1   ... Log_x_to_optical     HR_12_FINAL
#                                ...
# float32    float64    float64  ...     float64            float64
# -------- ----------- --------- ... ---------------- --------------------
# -30524.0 149.6958618 2.2645054 ...    30000000000.0 -0.12132822477650064
# -27948.0  149.700882 2.4025755 ...    30000000000.0  -0.2760975609756098
#  -4550.0 149.8696899 2.2940061 ...    30000000000.0  -0.3402777777777778
#  20691.0 149.9936371 2.2585292 ...    30000000000.0  -0.5375128468653648
#  -8036.0 150.2425537 1.7664008 ...    30000000000.0  -0.3453903837670931
#  -1361.0 150.2733917 1.9342152 ...    30000000000.0 -0.47451669595782076
#   3284.0 150.3359833 2.4337759 ...    30000000000.0 -0.32098765432098764
#  19376.0 149.6206665 2.6143165 ...    30000000000.0  0.10344827586206896
#  20828.0 149.5981598 2.6850221 ...    30000000000.0  -0.5204819277108433
# ...

# %%
plt.figure(1, figsize=(14, 7))
markersize=120
plt.scatter(C5['HR_12_FINAL'], C5['Log(X/0)'], color='blue', edgecolors= 'k', s= 150, cmap= 'Dark2', marker='D', linewidth=1, label='BC_AGN')
plt.scatter(C6['HR_12_FINAL'], C6['Log(X/0)'], color='green', edgecolors= 'k', s= 150, cmap= 'Dark2', marker='+', linewidth=5, label='GV_AGN')
plt.scatter(C7['HR_12_FINAL'], C7['Log(X/0)'], color='none', edgecolors= 'red', s= 150, cmap= 'Dark2', marker='s', linewidth=3, label='RS_AGN')
plt.axhline(y = -1, color = 'purple', linestyle = '-',  linewidth=3)
plt.vlines(x = -0.35, ymin = -1.5, ymax =1.5, colors = 'black', linewidth=3)
plt.ylim(-1.5, 1.5)
plt.xlabel('HR(2-5/0.5-2)kev', fontsize=25)
plt.ylabel('Log(X/O)', fontsize=25)
plt.rc('xtick',labelsize=25)
plt.rc('ytick',labelsize=25)
plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=18)
plt.savefig('file10.png',dpi=400)

plt.show()

# %%
plt.figure(1, figsize=(11, 8))
markersize=120
plt.scatter(B2['mass70'], B2['logSFR'], color='blue', edgecolors= 'k', s= 150, cmap= 'Dark2', marker='D', linewidth=1, label='BC_AGN')
plt.scatter(B3['mass70'], B3['logSFR'], color='green', edgecolors= 'k', s= 150, cmap= 'Dark2', marker='+', linewidth=5, label='GV_AGN')
plt.scatter(B4['mass70'], B4['logSFR'], color='none', edgecolors= 'red', s= 150, cmap= 'Dark2', marker='s', linewidth=3, label='RS_AGN')
plt.xlim(7, 12.5)
plt.ylim(-2, 4)



plt.ylabel('log $M_{\odot}$/ $yr$', fontsize=25)
plt.xlabel('log($M{_*}$)[$M_{\odot}$]', fontsize=25)
plt.rc('xtick',labelsize=25)
plt.rc('ytick',labelsize=25)
plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=18)
plt.savefig('file10.png',dpi=400)

plt.show()

# %%
fig, ax = plt.subplots(figsize =(14, 8))
plt.xlabel('Log(X/0)',fontsize=22)
plt.ylabel('Normalised number of  sources', fontsize=22)
#plt.xlim(-1, 2)

#plt.ylim(-1, 2)
data14=C5['Log(X/0)']
data15=C6['Log(X/0)']
data16=C7['Log(X/0)']
#bins=[-0.3,-0.12,-0.063,0.25,0.44,0.63, 0.81, 1]
#bins2=[-0.41,-0.22,-0.03,0.16,0.35,0.54,0.73,0.92,1.11,1.3]
#bins3= [-0.41,-0.22,-0.03,0.16,0.35,0.54,0.73,0.92,1.11,1.3,1.49,1.68]
#ax.hist(data14, color='blue',label='BC_AGN',    edgecolor='blue',linewidth=3,   histtype='step',density=True,alpha=0.9,fill=False, linestyle='solid', stacked=True)
#ax.hist(data15, color='green', label='GV_AGN',  edgecolor='green',linewidth=3, histtype='step',density=True,alpha=1,fill=False, linestyle='dashdot', stacked=True)
ax.hist(data16, color='red',label='RS_AGN',edgecolor='red',linewidth=3, histtype='step',density=True,alpha=1,fill=False, linestyle='dashed', stacked= True)
plt.rc('xtick',labelsize=23)
plt.rc('ytick',labelsize=23)
plt.savefig('file5.jpg',dpi=400)
plt.legend(loc=1,fontsize=16)
plt.show()

# %%
fig, ax = plt.subplots(figsize =(14, 8))
plt.xlabel('HR(2-5/0.5-2)kev',fontsize=22)
plt.ylabel('Normalised number of  sources', fontsize=22)
ax.set_xlim(-1, 0.8)
data4=C5['HR_12_FINAL']
data5=C6['HR_12_FINAL']
data6=C7['HR_12_FINAL']
bins1=[-0.652,-0.524,-0.396,-0.268,-0.14, -0.012,0.116, 0.244,0.372,0.5]
bins2=[-0.652,-0.524,-0.396,-0.268,-0.14, -0.012,0.116, 0.244,0.372,0.5,0.628]
bins3=[-0.652,-0.524,-0.396,-0.268,-0.14, -0.012,0.116, 0.244,0.372]
plt.hist(data4, color='blue',label='BC_AGN', bins= bins1,edgecolor='blue',linewidth=2.5,  histtype='step',density=True,alpha=1,fill=False, linestyle='solid')
plt.hist(data5, color='green',label='GV_AGN', bins= bins2 ,edgecolor='green',linewidth=2.5,histtype='step',density=True,alpha=1,fill=False, linestyle='dashdot')
plt.hist(data6, color='red',label='RS_AGN',bins= bins3,edgecolor='red',linewidth=2.5, histtype='step',density=True,alpha=1,fill=False, linestyle='dashed')
plt.rc('xtick',labelsize=23)
plt.rc('ytick',labelsize=23)
plt.savefig('file4.jpg',dpi=400)
plt.legend(loc=1,fontsize=16)
plt.show()

# %%
D1= Table.read('BCC1.fits')
D1
# Out:
# <Table masked=True length=414>
#   ID_1       RA_1      Dec_1   ...  HR_77   HR_88         HR_99
#                                ...
# float32    float64    float64  ... float64 float64       float64
# -------- ----------- --------- ... ------- ------- --------------------
#  10943.0 149.5549927 1.9885179 ...   -58.0   132.0  -0.4393939393939394
#  13069.0 149.5555573  2.093369 ...  -245.0   393.0  -0.6234096692111959
#  15913.0 149.5985413 2.2003093 ...     nan     nan                  nan
#  18334.0 149.5851898 1.9919548 ...     nan     nan                  nan
#  19805.0 149.6073608 2.0176179 ...     nan     nan                  nan
#  19895.0  149.595871 2.0407147 ...   -25.0   107.0  -0.2336448598130841
#  19962.0 149.5810089 2.0067356 ...     nan     nan                  nan
#  20026.0 149.5785065 2.0384471 ...     nan     nan                  nan
#  22299.0 149.6382141 2.1495957 ...   -25.0   373.0 -0.06702412868632708
# ...

# %%
D2= Table.read('BCC2.fits')
D2
# Out:
# <Table masked=True length=412>
#   ID_1       RA_1      Dec_1   ...  HR_77   HR_88         HR_99
#                                ...
# float32    float64    float64  ... float64 float64       float64
# -------- ----------- --------- ... ------- ------- --------------------
#  10943.0 149.5549927 1.9885179 ...   -58.0   132.0  -0.4393939393939394
#  13069.0 149.5555573  2.093369 ...  -245.0   393.0  -0.6234096692111959
#  15913.0 149.5985413 2.2003093 ...     nan     nan                  nan
#  18334.0 149.5851898 1.9919548 ...     nan     nan                  nan
#  19805.0 149.6073608 2.0176179 ...     nan     nan                  nan
#  19895.0  149.595871 2.0407147 ...   -25.0   107.0  -0.2336448598130841
#  19962.0 149.5810089 2.0067356 ...     nan     nan                  nan
#  20026.0 149.5785065 2.0384471 ...     nan     nan                  nan
#  22299.0 149.6382141 2.1495957 ...   -25.0   373.0 -0.06702412868632708
# ...

# %%
D3= Table.read('BCC3.fits')
D3
# Out:
# <Table masked=True length=406>
#   ID_1       RA_1      Dec_1   ...  HR_77   HR_88         HR_99
#                                ...
# float32    float64    float64  ... float64 float64       float64
# -------- ----------- --------- ... ------- ------- --------------------
#  10943.0 149.5549927 1.9885179 ...   -58.0   132.0  -0.4393939393939394
#  13069.0 149.5555573  2.093369 ...  -245.0   393.0  -0.6234096692111959
#  15913.0 149.5985413 2.2003093 ...     nan     nan                  nan
#  18334.0 149.5851898 1.9919548 ...     nan     nan                  nan
#  19805.0 149.6073608 2.0176179 ...     nan     nan                  nan
#  19895.0  149.595871 2.0407147 ...   -25.0   107.0  -0.2336448598130841
#  19962.0 149.5810089 2.0067356 ...     nan     nan                  nan
#  20026.0 149.5785065 2.0384471 ...     nan     nan                  nan
#  22299.0 149.6382141 2.1495957 ...   -25.0   373.0 -0.06702412868632708
# ...

# %%
fig, ax = plt.subplots(figsize =(14, 8))
plt.xlabel('logLx(0.5-10kev)[erg/sec]',fontsize=22)
plt.ylabel('Normalised number of  sources', fontsize=22)
#ax.set_ylim(0, 1.6)

data21=D1['log_kcorrected_luminocity_flux_f']
data22=D6['log_kcorrected_luminocity_flux_f']
data23=D7['log_kcorrected_luminocity_flux_f']
bins1=[40.55,41.1,41.65,42.2,42.75,43.3,43.85,44.4,44.95,45.5]
bins2=[41.85,42.2,42.55,42.9,43.25,43.6,43.95,44.3,44.65, 45]
bins3=[41.85,42.2,42.55,42.9,43.25,43.6,43.95,44.3,44.65, 45]

plt.hist(data21, color='blue',label='BC_AGN', align='right', bins= bins1,  edgecolor='blue',linewidth=2.5,histtype='step',density=True,alpha=1,fill=False, linestyle='solid', stacked=True)

plt.hist(data22, color='green',label='GV_AGN',bins= bins2,edgecolor='green',linewidth=2.5, histtype='step',density=True,alpha=1,fill=False, linestyle='dashdot',stacked=True)

plt.hist(data23, color='red',align='mid',label='RS_AGN',bins= bins3,edgecolor='red',linewidth=2.5, histtype='step',density=True,alpha=1,fill=False, linestyle='dashed',stacked=True)

plt.rc('xtick',labelsize=23)
plt.rc('ytick',labelsize=23)
plt.savefig('file4.jpg',dpi=400)
plt.legend(loc=1,fontsize=16)
plt.savefig('file6.jpg',dpi=400)

plt.show()

# %%
fig, ax = plt.subplots(figsize =(14, 8))
plt.xlabel('logLx(2-10kev) [erg/sec]',fontsize=22)
plt.ylabel('Normalised number of  sources', fontsize=22)
#ax.set_ylim(0, 1.6)

data24=D1['log_kcorrected_luminocity_flux_H']
data25=D5['log_kcorrected_luminocity_flux_H']
data26=D8['log_kcorrected_luminocity_flux_H']

bins1=[40.52,41.04,41.56,42.08, 42.6,43.12,43.64,44.16,44.68,45.25]
bins2=[41.85,42.2,42.55,42.9,43.25,43.6,43.95,44.3,44.65, 45]
bins3=[41.85,42.2,42.55,42.9,43.25,43.6,43.95,44.3,44.65, 45]

plt.hist(data24,color='blue',label='GV_AGN', bins= bins1,  edgecolor='blue',linewidth=2.5,histtype='step',density=True,alpha=1,fill=False, linestyle='solid', stacked=True)

plt.hist(data25, color='green',label='RS_AGN',bins= bins2,edgecolor='green',linewidth=2.5, histtype='step',density=True,alpha=1,fill=False, linestyle='dashdot',stacked=True)

plt.hist(data26, color='red',label='RS_AGN',bins= bins2,edgecolor='red',linewidth=2.5, histtype='step',density=True,alpha=1,fill=False, linestyle='dashed',stacked=True)

plt.rc('xtick',labelsize=23)
plt.rc('ytick',labelsize=23)
plt.savefig('file4.jpg',dpi=400)
plt.legend(loc=1,fontsize=16)
plt.show()

# %%
fig, ax = plt.subplots(figsize =(14, 8))
plt.xlabel('logLx(0.5-2kev)[erg/sec]',fontsize=22)
plt.ylabel('Normalised number of  sources', fontsize=22)
#ax.set_ylim(0, 1.6)

data34=D1['log_kcorrected_luminocity_flux_s']
data35=D4['log_kcorrected_luminocity_flux_s']
data36=D8['log_kcorrected_luminocity_flux_s']

bins1=[40.03,40.56,41.09,41.62,42.15,42.68,43.21,43.74,44.27,44.8]
bins2=[41.85,42.2,42.55,42.9,43.25,43.6,43.95,44.3,44.65, 45]
bins3=[40.5,41,41.5,42,42.5,43,43.5,44,44.5, 45]

plt.hist(data34, align='right', color='blue',label='BC_AGN', bins= bins1,  edgecolor='blue',linewidth=2.5,histtype='step',density=True,alpha=1,fill=False, linestyle='solid', stacked=True)

plt.hist(data35, align='mid', color='green',label='GV_AGN',bins=bins2, edgecolor='green',linewidth=2.5, histtype='step',density=True,alpha=1,fill=False, linestyle='dashdot',stacked=True)

plt.hist(data36,  color='red',label='RS_AGN',bins= bins3,edgecolor='red',linewidth=2.5, histtype='step',density=True,alpha=1,fill=False, linestyle='dashed',stacked=True)

plt.rc('xtick',labelsize=23)
plt.rc('ytick',labelsize=23)
plt.savefig('file4.jpg',dpi=400)
plt.legend(loc=1,fontsize=16)
plt.show()

# %%
D4= Table.read('GVV1.fits')
D4
# Out:
# <Table masked=True length=552>
#   ID_1       RA_1      Dec_1   ...  HR_77   HR_88         HR_99
#                                ...
# float32    float64    float64  ... float64 float64       float64
# -------- ----------- --------- ... ------- ------- -------------------
#   8362.0 149.5439148 1.8673762 ...     nan     nan                 nan
#   9649.0 149.5184937 1.9075274 ...    15.0   133.0 0.11278195488721804
#  12014.0  149.526001 2.0204754 ...   -68.0   236.0  -0.288135593220339
#  13008.0 149.5648956 2.0923908 ...     nan     nan                 nan
#  18402.0 149.5703735 1.9905663 ...   -82.0   272.0 -0.3014705882352941
#  18417.0  149.563858 1.9630669 ...     nan     nan                 nan
#  21151.0 149.6051331 2.0522935 ...   -50.0    50.0                -1.0
#  22219.0 149.6411133 2.1076314 ...     nan     nan                 nan
#  25677.0  149.648819 2.2327533 ...    75.0    75.0                 1.0
# ...

# %%
D5= Table.read('GVV2.fits')
D5
# Out:
# <Table masked=True length=552>
#   ID_1       RA_1      Dec_1   ...  HR_77   HR_88         HR_99
#                                ...
# float32    float64    float64  ... float64 float64       float64
# -------- ----------- --------- ... ------- ------- -------------------
#   8362.0 149.5439148 1.8673762 ...     nan     nan                 nan
#   9649.0 149.5184937 1.9075274 ...    15.0   133.0 0.11278195488721804
#  12014.0  149.526001 2.0204754 ...   -68.0   236.0  -0.288135593220339
#  13008.0 149.5648956 2.0923908 ...     nan     nan                 nan
#  18402.0 149.5703735 1.9905663 ...   -82.0   272.0 -0.3014705882352941
#  18417.0  149.563858 1.9630669 ...     nan     nan                 nan
#  21151.0 149.6051331 2.0522935 ...   -50.0    50.0                -1.0
#  22219.0 149.6411133 2.1076314 ...     nan     nan                 nan
#  25677.0  149.648819 2.2327533 ...    75.0    75.0                 1.0
# ...

# %%
D6= Table.read('GVV3.fits')
D6
# Out:
# <Table masked=True length=549>
#   ID_1       RA_1      Dec_1   ...  HR_77   HR_88         HR_99
#                                ...
# float32    float64    float64  ... float64 float64       float64
# -------- ----------- --------- ... ------- ------- -------------------
#   8362.0 149.5439148 1.8673762 ...     nan     nan                 nan
#   9649.0 149.5184937 1.9075274 ...    15.0   133.0 0.11278195488721804
#  12014.0  149.526001 2.0204754 ...   -68.0   236.0  -0.288135593220339
#  13008.0 149.5648956 2.0923908 ...     nan     nan                 nan
#  18402.0 149.5703735 1.9905663 ...   -82.0   272.0 -0.3014705882352941
#  18417.0  149.563858 1.9630669 ...     nan     nan                 nan
#  21151.0 149.6051331 2.0522935 ...   -50.0    50.0                -1.0
#  22219.0 149.6411133 2.1076314 ...     nan     nan                 nan
#  25677.0  149.648819 2.2327533 ...    75.0    75.0                 1.0
# ...

# %%
D7= Table.read('RSS1.fits')
D7
# Out:
# <Table masked=True length=262>
#   ID_1       RA_1      Dec_1   ...  HR_77   HR_88         HR_99
#                                ...
# float32    float64    float64  ... float64 float64       float64
# -------- ----------- --------- ... ------- ------- --------------------
#  12228.0  149.561264 2.0091538 ...   -68.0    68.0                 -1.0
#  18374.0 149.5786896 2.0017781 ...   -50.0    50.0                 -1.0
#  23918.0 149.6211243 2.1810327 ...     nan     nan                  nan
#  25624.0 149.6496277 2.2092495 ...     nan     nan                  nan
#  25864.0 149.6217651 2.2170653 ...     nan     nan                  nan
#  26673.0 149.6625214 2.2695825 ...   -74.0   212.0  -0.3490566037735849
#  27484.0 149.6393127 2.0031817 ...     8.0   216.0 0.037037037037037035
# -30660.0 149.6806946  2.268281 ...    62.0    62.0                  1.0
# -30524.0 149.6958618 2.2645054 ...   -29.0   849.0 -0.03415783274440518
# ...

# %%
D8= Table.read('RSS2.fits')
D8
# Out:
# <Table masked=True length=263>
#   ID_1       RA_1      Dec_1   ...  HR_77   HR_88         HR_99
#                                ...
# float32    float64    float64  ... float64 float64       float64
# -------- ----------- --------- ... ------- ------- --------------------
#  12228.0  149.561264 2.0091538 ...   -68.0    68.0                 -1.0
#  18374.0 149.5786896 2.0017781 ...   -50.0    50.0                 -1.0
#  23918.0 149.6211243 2.1810327 ...     nan     nan                  nan
#  25624.0 149.6496277 2.2092495 ...     nan     nan                  nan
#  25864.0 149.6217651 2.2170653 ...     nan     nan                  nan
#  26673.0 149.6625214 2.2695825 ...   -74.0   212.0  -0.3490566037735849
#  27484.0 149.6393127 2.0031817 ...     8.0   216.0 0.037037037037037035
# -30660.0 149.6806946  2.268281 ...    62.0    62.0                  1.0
# -30524.0 149.6958618 2.2645054 ...   -29.0   849.0 -0.03415783274440518
# ...

# %%
D9= Table.read('RSS3.fits')
D9
# Out:
# <Table masked=True length=269>
#   ID_1       RA_1      Dec_1   ...  HR_77   HR_88         HR_99
#                                ...
# float32    float64    float64  ... float64 float64       float64
# -------- ----------- --------- ... ------- ------- --------------------
#  12228.0  149.561264 2.0091538 ...   -68.0    68.0                 -1.0
#  18374.0 149.5786896 2.0017781 ...   -50.0    50.0                 -1.0
#  23918.0 149.6211243 2.1810327 ...     nan     nan                  nan
#  25624.0 149.6496277 2.2092495 ...     nan     nan                  nan
#  25864.0 149.6217651 2.2170653 ...     nan     nan                  nan
#  26673.0 149.6625214 2.2695825 ...   -74.0   212.0  -0.3490566037735849
#  27484.0 149.6393127 2.0031817 ...     8.0   216.0 0.037037037037037035
# -30660.0 149.6806946  2.268281 ...    62.0    62.0                  1.0
# -30524.0 149.6958618 2.2645054 ...   -29.0   849.0 -0.03415783274440518
# ...

# %%
F1= Table.read('bc.fits')
F1
# Out:
# <Table masked=True length=38>
#   ID_1       RA_1      Dec_1   ...  HR_77   HR_88         HR_99
#                                ...
# float32    float64    float64  ... float64 float64       float64
# -------- ----------- --------- ... ------- ------- --------------------
#  22299.0 149.6382141 2.1495957 ...   -25.0   373.0 -0.06702412868632708
# -29501.0 149.7207336 2.3489881 ...  -762.0  1462.0   -0.521203830369357
# -26732.0 149.7058258 2.4198005 ... -1293.0  2047.0  -0.6316560820713238
# -23019.0 149.7710724 2.2584734 ...  -348.0  1032.0  -0.3372093023255814
# -13216.0 149.8340454 2.3087234 ...  -261.0   755.0  -0.3456953642384106
#  -5927.0 149.8590546 2.2582619 ...  -331.0   955.0 -0.34659685863874345
#  -2415.0 149.8842621 2.3380821 ...   220.0   312.0   0.7051282051282052
#   6569.0  149.936615 2.6802056 ...  -985.0  1899.0  -0.5186940494997367
#  10076.0 149.9556122 2.5020289 ...  -391.0  1019.0  -0.3837095191364082
# ...

# %%
F2= Table.read('gv.fits')
F2
# Out:
# <Table masked=True length=53>
#   ID_1       RA_1      Dec_1   ...  HR_77   HR_88         HR_99
#                                ...
# float32    float64    float64  ... float64 float64       float64
# -------- ----------- --------- ... ------- ------- --------------------
#  28917.0   149.66922 2.0740416 ...  -331.0  1289.0 -0.25678820791311097
# -28267.0    149.7388 2.3663437 ...  -195.0   513.0 -0.38011695906432746
# -21998.0 149.7383575 1.9787644 ...   152.0   230.0   0.6608695652173913
# -18641.0 149.7681274 2.4313455 ...    72.0   652.0  0.11042944785276074
# -17759.0 149.7819061 2.1390696 ...  -251.0   751.0 -0.33422103861517977
# -12899.0 149.7897644 2.3212087 ... -1514.0  2802.0  -0.5403283369022127
#  -8450.0 149.8620453 1.8948123 ...   -15.0   723.0 -0.02074688796680498
#  -1628.0 149.8935547 2.1076827 ...  -326.0   746.0 -0.43699731903485256
#   5768.0 149.9323883 2.3354716 ...    99.0   201.0   0.4925373134328358
# ...

# %%
F3= Table.read('rs.fits')
F3
# Out:
# <Table masked=True length=14>
#   ID_1       RA_1      Dec_1   ...  HR_77   HR_88         HR_99
#                                ...
# float32    float64    float64  ... float64 float64       float64
# -------- ----------- --------- ... ------- ------- --------------------
# -30524.0 149.6958618 2.2645054 ...   -29.0   849.0 -0.03415783274440518
# -27948.0  149.700882 2.4025755 ...  -251.0  2365.0 -0.10613107822410148
#  20691.0 149.9936371 2.2585292 ...  -468.0  1028.0 -0.45525291828793774
#  -8036.0 150.2425537 1.7664008 ...  -503.0  2547.0 -0.19748723989006675
#  -1361.0 150.2733917 1.9342152 ...  -421.0  1257.0  -0.3349244232299125
#   3284.0 150.3359833 2.4337759 ...   -70.0   572.0 -0.12237762237762238
#  19376.0 149.6206665 2.6143165 ...    78.0   182.0  0.42857142857142855
#  20828.0 149.5981598 2.6850221 ...  -347.0   915.0 -0.37923497267759565
#  27750.0 149.6557007 2.6008053 ...  -711.0  2713.0 -0.26207150755621084
# ...

# %%
fig, ax = plt.subplots(figsize =(14, 8))
plt.xlabel('logLx(5-10kev) [erg/sec]',fontsize=22)
plt.ylabel('Normalised number of  sources', fontsize=22)
#ax.set_ylim(0, 1.6)

#ax.set_xlim(43, 45)
data11=F1['log_510']
data12=F2['log_510']
data13=F3['log_510']
b= 10 # Number of bins
#Xmax= 45
#Xmin=43
#a= Xmax- Xmin  

bins=(43.2, 43.4, 43.6, 43.8, 44, 44.2, 44.4, 44.6,44.8,45)

bins2=(41.4, 41.8, 42.2, 42.6, 43, 43.4, 43.8, 44.2,44.4,44.8, 45)

bins3=(41.85, 42.35, 42.85, 43.35, 43.85, 44.35, 44.85,45.35)


plt.hist(data11,  bins=bins,color='blue',label='GV_AGN',  edgecolor='blue',linewidth=2.5,histtype='step',density=True,alpha=1,fill=False, linestyle='solid', stacked=True)

plt.hist(data12, color='green', bins=bins2, label='RS_AGN',edgecolor='green',linewidth=2.5, histtype='step',density=True,alpha=1,fill=False, linestyle='dashdot',stacked=True)

plt.hist(data13, color='red',bins=bins3, align='left', label='RS_AGN',edgecolor='red',linewidth=2.5, histtype='step',density=True,alpha=1,fill=False, linestyle='dashed',stacked=True)

plt.rc('xtick',labelsize=23)
plt.rc('ytick',labelsize=23)
plt.savefig('file4.jpg',dpi=400)
plt.legend(loc=1,fontsize=16)
plt.show()

# %%
#

# %%
fig, ax = plt.subplots(figsize =(14, 8))
plt.xlabel('logL21cm',fontsize=22)
plt.ylabel('Normalised number of sources', fontsize=22)
#ax.set_xlim(-29, -14)
#ax.set_ylim(0, 0.5)

data11=B2['logL21cm']
data12=B3['logL21cm']
data13=B4['logL21cm']
b= 10 # Number of bins
#Xmax= 45
#Xmin=43
#a= Xmax- Xmin  

bins=(22.03,22.56,23.09,23.62,24.15,24.68,25.21,25.74,26.27,26.8)
bins2=(21.97,22.44,22.91,23.38,23.85,24.32,24.79,25.26,25.73,26.2)
bins3=(22.29,22.68,23.07, 23.46,23.85,24.24,24.63,25.02,25.41,25.8)


plt.hist(data11, align='left', color='blue',label='BC_AGN',bins=bins,edgecolor='blue',linewidth=3,lw=3.5,fill=False,histtype='step', linestyle='solid',density=True)
plt.hist(B3['logL21cm'], align='right',color='green',label='GV_AGN',bins=bins2,edgecolor='green',linewidth=3,lw=3.5,fill=False,histtype='step',linestyle='dashdot',density=True)
plt.hist(B4['logL21cm'], align='left', color='red',label='RS_AGN',bins=bins3,edgecolor='red',linewidth=3,lw=4.5,fill=False,histtype='step',linestyle='dashed',density=True)
title= fig.suptitle("AGN_selection_of_BC_GV_RS",fontsize=22)
plt.rc('xtick',labelsize=23)
plt.rc('ytick',labelsize=23)
plt.savefig('file4.jpg',dpi=400)
plt.legend(loc=1,fontsize=16)
