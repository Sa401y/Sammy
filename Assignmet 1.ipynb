# %% [markdown]
# ##   $$Computational  Astrophysics$$
#
# ## Q1. Here, from the Stefan-Boltzmann law, the Luminosity of those stars is given by:
#
# ### L= $\ 4\pi R^{2}\sigma T^{4}$ , σ= 5.67e-8   where T, = 5.67 *10e-8 W/m $^{2} /k^{4}$ ,  and R are the effective temperature in kelvin,  G = 6.67e - 11 Nm$^{2} / kg^{2}$   is the gravational  force of attraction from Newton Law  and   $R_{\odot}$ = 6.96e+8m is  Radius  of the sun   $M_ {\odot}$ = 1.99e+30 kg is Mass of the sun  $T_{\odot}$=  5800$^{o}$k   Temperature of  Sun in kelvin.
#
# ###  TW And: 1.1-1.68  $M1_{\odot }$  from 0.1 − 0.32  $M2_{\odot}$  1.25 − 2.19$R1_{\odot}$ ,1.56 − 3.37$R2_{\odot}$ , ranges from 1.25-3.86k    $logT 1 _{\odot}$ , from 1.6-3.622k   $logT2_{\odot}$

# %%
## 1  Question 

import numpy as np
import matplotlib.pyplot as plt
from numpy import pi
M1=np.linspace(1.1,1.68,100)
M2=np.linspace(0.1,0.32,100)
R1=np.linspace(1.25,2.19,100)
R2=np.linspace(1.56,3.37,100 )
T1=np.linspace(17.78279410038923,7244.359600749898,100) 
T2=np.linspace(39.810717055349734, 4187.935651179182,100)  


Msun=1.99e+30 # Mass of our Sun
Rsun=6.96e+8  # Radius of our Sun 

sigma= 5.67e-8
L1= 4 * pi * R1**2 * sigma * T1**4
L2= 4 * pi  * R2**2 * sigma  * T2**4
plt.figure(figsize=(12,8))
## R1 VS L1,L2
plt.ylabel('$ L1_{\odot} }$ & $ L2_{\odot} }$\n interms of solar-system',fontsize=25)
plt.xlabel('$(R1_{\odot})}$ in $meter $ \n interms of solar-system ',fontsize=25)
plt.plot(R1,L1, 'm', label=' R1 vs L1', linewidth=5)
plt.plot(R1,L2, 'g', label=' R1 vs L2', linewidth=5)
plt.title('TW Binary Stars',fontsize=20)
plt.legend(loc=2,fontsize=20)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.ylabel('$ L1_{\odot} }$ & $ L2_{\odot} }$\n interms of solar-system',fontsize=25)
plt.xlabel('$(R2_{\odot})}$ in $meter $ \n interms of solar system ',fontsize=25)
plt.plot(R2,L1, 'b', label='R2 vs L1', linewidth=5)
plt.plot(R2,L2, 'g', label='R2 vs L2', linewidth=5)
plt.title('TW Binary Stars',fontsize=20)
plt.legend(loc =2 ,fontsize=20)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.ylabel('$ L1_{\odot} }$ & $ L2_{\odot} }$\n interms of solar-system',fontsize=25)
plt.xlabel('$ (T1_{\odot}}$$ ^{o}k$) \n interms of solar-system',fontsize=25)
plt.plot(T1, L1, 'r', label='T1 vs L1', linewidth=5)
plt.plot(T1, L2, 'k', label='T1 vs L2', linewidth=5)
plt.title('TW Binary Stars',fontsize=20)
plt.legend(loc=2,fontsize=20)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.ylabel('$ L1_{\odot}}$ & $ L2_{\odot} }$\n interms of solar-system',fontsize=25)
plt.xlabel('$ (T2_{\odot}}$$ ^{o}k$) \n interms of solar-system',fontsize=25)
plt.plot(T2, L1 , 'g', label='T2 vs L1', linewidth=5)
plt.plot(T2, L2, 'm', label='T2 vs L2', linewidth=5)
plt.title('TW Binary Stars',fontsize=20)
plt.legend(loc=2,fontsize=20)
plt.show()

# %%
## 2  Question 

import numpy as np
import pylab
import matplotlib.pyplot as plt
from numpy import pi
Ma=np.linspace(1.0,2.26,1000)
Md=np.linspace(0.2,0.5,1000)
Ra=np.linspace(1.12,1.70,1000)
Rd=np.linspace(1.30,3.3,1000)
Ta=np.linspace(31.622776601683793,10000.0,1000) # are changed in Logartism forms
Td=np.linspace(63.09573444801933, 4677.351412871981,1000) #  are changed in Logartism forms
sigma= 5.67e-8
La=4 * pi * Ra**2  *  sigma *  Ta**4
Ld=4 * pi * Rd**2 *  sigma *  Td**4
plt.figure(figsize=(12,8))
plt.ylabel('$ La_{\odot}}$ & $ Ld_{\odot} }$\n interms of solar-system',fontsize=25)
plt.xlabel('$(Ra_{\odot})}$in $meter$  \n interms of solar-system',fontsize=25)
plt.plot(Ra,La, 'm', label='Ra vs La', linewidth=5)
plt.plot(Ra,Ld, 'b', label='Ra vs Ld', linewidth=5)
plt.title('KO Aql binary star',fontsize=20)
plt.legend(loc=2,fontsize=20)
plt.show()

# %%
## Rd vs La ,Ld
plt.figure(figsize=(12,8))
plt.ylabel('$ La_{\odot}}$ & $ Ld_{\odot} }$\n interms of solar-system',fontsize=25)
plt.xlabel('$(Rd_{\odot})}$in $meter$ \n interms of solar-system',fontsize=25)
plt.plot(Rd,La, 'b', label='Rd vs La', linewidth=5)
plt.plot(Rd,Ld, 'g', label='Rd vs Ld', linewidth=5)
plt.title('KO Aql binary star',fontsize=20)
plt.legend(loc=2,fontsize=20)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.ylabel('$ La_{\odot}}$ & $ Ld_{\odot}}$\n interms of solar-system',fontsize=25)
plt.xlabel('$(Ta_{\odot})}$ $ ^{o}k$ \n interms of solar-system',fontsize=25)
plt.plot(Ta,La, 'b', label='Ta vs.La', linewidth=5)
plt.plot(Ta,Ld, 'r', label='Ta vs Ld', linewidth=5)
plt.title('KO Aql binary star',fontsize=20)
plt.legend(loc=2,fontsize=20)
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.ylabel('$ La_{\odot} }$ & $ Ld_{\odot}}$\n interms of solar-system',fontsize=25)
plt.xlabel('$(Td_{\odot})}$ $^{o}k$ KoAql \n interms of solar-system',fontsize=25)
## Td vs La ,Ld
plt.plot(Td,La, 'r', label='Td vs.La', linewidth=5)
plt.plot(Td,Ld, 'g', label='Td vs Ld', linewidth=5)
plt.title('KO Aql binary star',fontsize=20)
plt.legend(loc=2,fontsize=20)
plt.show()

# %% [markdown]
# ### 3 Thrid Question determineing  the age of two binary stars  "TW And" and " KOAQLl" of binary stars

# %%
## TW Binary Stars 

M1=np.linspace(1.1,1.68,1000)
M2=np.linspace(0.1,0.32,1000)
Ma=np.linspace(1.0,2.26,1000)
Md=np.linspace(0.2,0.5,1000)
# M1,M2,Ma,Md are in solar masses
t1= 10e+10* (1/ M1)**2.9
t2= 10e+10* (1/M2)**2.9
ta= 10e+10* (1/ Ma)**2.9
td= 10e+10* (1/ Md)**2.9
plt.figure(figsize=(14,7))
plt.plot(t1,M1,'b',label='t1 vs M1',linewidth=4)
plt.xlabel('$t1_{\odot}$ \n interms of period',fontsize=20)
plt.ylabel('$M1(M_{\odot})$\n interms of kg',fontsize=20)
plt.title('TW of stars', fontsize=20)
plt.legend(loc=1,fontsize=20)
plt.show()

# %%
plt.figure(figsize=(14,7))
plt.plot(t2,M2,'r',label='t1 vs M1',linewidth=4)
plt.xlabel('$t2_{\odot}$ \n interms of period',fontsize=20)
plt.ylabel('$M2(M_{\odot})$\n interms of kg',fontsize=20)
plt.title('TW of stars', fontsize=20)
plt.legend(loc=1,fontsize=20)
plt.show()

# %%
plt.figure(figsize=(14,7))
plt.plot(ta,Ma,'g',label='td  vs md',linewidth=4)
plt.xlabel('$td_{\odot}$\n interms of period',fontsize=20)
plt.ylabel('$Md(M_{\odot})$\n interms of kg',fontsize=20)
plt.title('KO of stars', fontsize=20)
plt.legend(loc=1,fontsize=20)
plt.show()

# %%
plt.figure(figsize=(14,7))
plt.plot(td,Md,'m',label='td  vs md',linewidth=4)
plt.xlabel('$td_{\odot}$\n interms of period',fontsize=20)
plt.ylabel('$Md(M_{\odot})$\n interms of  kg',fontsize=20)
plt.title('KO of stars', fontsize=20)
plt.legend(loc=1,fontsize=20)
plt.show()

# %% [markdown]
# # $$Explanation $$

# %% [markdown]
# ###  when I  explan  each of the  stars  from the graph  R1 vs L1, L2 are  directely proportional to each other  meaning   the higher the radius  the higer it L1 or L2   and they  have  an increassing  Exoponential Function .   For both L1 and L2  the  L1 lie  above L2   For the second  one meaning for R2 vs L1,L2  has same direct relationship with the first one  but  L2  lies above L1 .  When I come to Temperature what I notcied is similar   with L1 and L2  the higher it radius the higher it Temperature. To conclude  both of the binary stars have shown from there parameter  such as  Temperature , Luminosity and Radius  have an increaseing exoponential Function  .  they are directly proportinal toward one another note that the bigger the radius  the higher the temperature  and Luminosity. Note that  massive stars have high Luminosity , Temperature and Radius than the smaller mass  Stars.  from this formula  $$L= 4\pi r^{2} \sigma{T^{4}} $$   What it can tell us  from the above formula  is Luminosity is directly proportional to both  the radius and temperature.
#
#
# ###  3.  explaination for  determineing  the age of two binary stars  "TW And" and " KOAQLl" of binary stars when we compare both their life time the smaller one live longer than the bigger one so  their inverse relationship between mass and time the higher the mass the shorter it life. Stars with the Smaller mass tends to leave longer than a star with a bigger one which means a star with shorter one tends to leave 10000 times the one the bigger stars mass.
